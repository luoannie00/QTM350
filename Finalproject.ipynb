# %%
import boto3
import json
import numpy as np
import pandas as pd

# %%
def detect_faces(photo, bucket):

    client=boto3.client('rekognition')

    response = client.detect_faces(Image={'S3Object':{'Bucket':bucket,'Name':photo}},Attributes=['ALL'])

    print('Detected faces for ' + photo)    
    for faceDetail in response['FaceDetails']:
        print('The detected face is between ' + str(faceDetail['AgeRange']['Low']) 
              + ' and ' + str(faceDetail['AgeRange']['High']) + ' years old')

        print('Here are the other attributes:')
        print(json.dumps(faceDetail, indent=4, sort_keys=True))

		# Access predictions for individual face details and print them
        print("Gender: " + str(faceDetail['Gender']))
        print("Smile: " + str(faceDetail['Smile']))
        print("Eyeglasses: " + str(faceDetail['Eyeglasses']))
        print("Emotions: " + str(faceDetail['Emotions'][0]))

    return len(response['FaceDetails'])

# %%
detect_faces('E8EO8X5UcAAAaIj.jpeg','qtm350assets')
# Out:
# Detected faces for E8EO8X5UcAAAaIj.jpeg
# The detected face is between 10 and 18 years old
# Here are the other attributes:
# {
#     "AgeRange": {
#         "High": 18,
#         "Low": 10
#     },
#     "Beard": {
#         "Confidence": 93.33496856689453,
#         "Value": false
#     },
#     "BoundingBox": {
#         "Height": 0.43361860513687134,
#         "Left": 0.39252662658691406,
#         "Top": 0.10755053907632828,
#         "Width": 0.3104667663574219
#     },
#     "Confidence": 99.99993896484375,
#     "Emotions": [
#         {
#             "Confidence": 66.49885559082031,
#             "Type": "CALM"
#         },
#         {
#             "Confidence": 10.849970817565918,
#             "Type": "SURPRISED"
#         },
#         {
#             "Confidence": 8.369634628295898,
#             "Type": "FEAR"
#         },
#         {
#             "Confidence": 5.852461338043213,
#             "Type": "DISGUSTED"
#         },
#         {
# ...

# %%
s3_resource = boto3.resource('s3')
my_bucket = s3_resource.Bucket('final-project-qtm350')
summaries = my_bucket.objects.all()
image_names = [image.key for image  in summaries]
image_names
# Out:
# ['1637344730-image.png',
#  'E8EO8X5UcAAAaIj.jpeg',
#  'iu-broker-cannes-2022-Getty-Images-300522.jpeg']

# %%
df = pd.DataFrame({'Name':image_names})
df['Similarity'] = [detect_faces(photo, bucket) for photo in df['Name']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-8197cb0cc9fb> in <module>
#       1 df = pd.DataFrame({'Name':image_names})
# ----> 2 df['Similarity'] = [detect_faces(photo, bucket) for photo in df['Name']]
#
# <ipython-input-23-8197cb0cc9fb> in <listcomp>(.0)
#       1 df = pd.DataFrame({'Name':image_names})
# ----> 2 df['Similarity'] = [detect_faces(photo, bucket) for photo in df['Name']]
#
# NameError: name 'bucket' is not defined
